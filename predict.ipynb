# %% [markdown]
# <a href="https://colab.research.google.com/github/csanny/Survice-BERT/blob/main/predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 1ZA6QHJC-VzDgr-bN29ti8JajagVtQR7k
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZA6QHJC-VzDgr-bN29ti8JajagVtQR7k
# To: /content/Survice-BERT_V4_lr3_8-8.pt
# 100% 442M/442M [00:02<00:00, 203MB/s]

# %%
# !pip install numpy==1.22.2
# !pip install pandas==1.4.4
# !pip install NERDA==0.9.6
# !pip install torch==1.13.1

import numpy as np
import pandas as pd 
from NERDA.models import NERDA
import torch
import os
from google.colab import drive
import nltk
nltk.download('punkt')

pd.set_option('display.max_rows', 500)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
model = torch.load('/content/Survice-BERT_V4_lr3_8-8.pt')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.24.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
sentence1 = 'A total of 3 cases of MVE virus infection and 2 deaths have been reported in Victoria this mosquito season.'
predict_result = model.predict_text(sentence1)

pd.DataFrame({'value':predict_result[0][0], 'ner_v1':predict_result[1][0]})
# Out:
#         value     ner_v1
# 0           A          O
# 1       total          O
# 2          of          O
# 3           3     B-CASE
# 4       cases          O
# 5          of          O
# 6         MVE  B-DISEASE
# 7       virus  I-DISEASE
# 8   infection          O
# 9         and          O
# 10          2    B-DEATH
# 11     deaths          O
# 12       have          O
# 13       been          O
# 14   reported          O
# 15         in          O
# 16   Victoria      B-LOC
# 17       this          O
# 18   mosquito          O
# 19     season          O
# 20          .          O

# %%
sentence2 = '•	From 1 November 2022 to 27 January 2023, a total of 559 cases of meningitis (of which 111 are laboratory confirmed), including 18 deaths (overall CFR 3.2%), have been reported from Zinder Region, southeast of Niger, compared to the 231 cases reported during 1 November 2021 to 31 January 2022.'
predict_result = model.predict_text(sentence2)

pd.DataFrame({'value':predict_result[0][0], 'ner_v1':predict_result[1][0]})
# Out:
#          value        ner_v1
# 0            •             O
# 1         From             O
# 2            1    B-DATE_DAY
# 3     November  B-DATE_MONTH
# 4         2022   B-DATE_YEAR
# 5           to             O
# 6           27    B-DATE_DAY
# 7      January  B-DATE_MONTH
# 8         2023   B-DATE_YEAR
# 9            ,             O
# 10           a             O
# 11       total             O
# 12          of             O
# 13         559        B-CASE
# 14       cases             O
# 15          of             O
# 16  meningitis     B-DISEASE
# 17           (             O
# 18          of             O
# 19       which             O
# 20         111        B-CASE
# 21         are             O
# 22  laboratory             O
# 23   confirmed             O
# 24           )             O
# 25           ,             O
# 26   including             O
# 27          18       B-DEATH
# 28      deaths             O
# 29           (             O
# 30     overall             O
# ...
